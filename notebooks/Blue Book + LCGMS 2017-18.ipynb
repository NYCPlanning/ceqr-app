# %%
import pandas as pd
import datetime

# %%
lcgmsRaw = pd.read_csv('data/LCGMS_SchoolData_20180724_1606.csv')

# %%
lcgmsRaw.dtypes
# Out:
# ATS System Code                           object
# Location Code                             object
# Location Name                             object
# BEDS Number                              float64
# Managed By Name                           object
# Location Type Description                 object
# Location Category Description             object
# Grades                                    object
# Grades Final                              object
# Open Date                                 object
# Status Description                        object
# Building Code                             object
# Primary Address                           object
# City                                      object
# State Code                                object
# Zip                                        int64
# Borough Block Lot                        float64
# Census Tract                             float64
# Community District                       float64
# ...

# %%
lcgmsRaw['Open Date'] = pd.to_datetime(lcgmsRaw['Open Date'])

# %%
lcgmsRaw[
    (lcgmsRaw['Open Date'] > datetime.date(2017,1,1)) 
    & 
    (lcgmsRaw['Managed By Name'] == 'DOE')
]
# Out:
#      ATS System Code Location Code                        Location Name  \
# 78            02M297          M297                             M.S. 297
# 211           04M310          M310       THE JUDITH S. KAYE HIGH SCHOOL
# 334           07X584          X584                             I.S. 584
# 388           08X583          X583                             P.S. 583
# 457           09X593          X593                             M.S. 593
# 458           09X594          X594                             M.S. 594
# 651           12X595          X595                             P.S. 595
# 784           15K896          K896                             P.S. 896
# 808           16K898          K898                             M.S. 898
# 938           19K907          K907                             M.S. 907
# 1063          22K889          K889                             P.S. 889
# 1064          22K890          K890                             M.S. 890
# ...
